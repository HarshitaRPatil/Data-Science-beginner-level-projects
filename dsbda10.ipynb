# %%
import pandas as pd

# %%
import numpy as nm

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iris.csv')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.boxplot(x='SepalLengthCm', data=df)
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %%
sns.boxplot(x='SepalWidthCm', data=df)
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
sns.boxplot(x='PetalLengthCm', data=df)
# Out:
# <Axes: xlabel='PetalLengthCm'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
def graph(y):
     sns.boxplot(x='Species',y=y,data=df)

plt.subplot(221)
graph('SepalWidthCm')

plt.subplot(222)
graph('SepalLengthCm')

plt.subplot(223)
graph('PetalWidthCm')

plt.subplot(224)
graph('PetalLengthCm')

plt.show()

# %%
Q1=nm.percentile(df['SepalWidthCm'],25,interpolation='midpoint')

# %%
print(Q1)
# Out:
# 2.8

# %%
Q3=nm.percentile(df['SepalWidthCm'],75,interpolation='midpoint')

# %%
IQR=Q3-Q1

# %%
df.shape
# Out:
# (150, 6)

# %%
upper=nm.where(df['SepalWidthCm']>=(Q3+1.5*IQR))

# %%
ower=nm.where(df['SepalWidthCm']<=(Q1-1.5*IQR))

# %%
df.drop(upper[0],inplace=True)

# %%
lower = [0]
df.drop(lower[0],inplace=True)

# %%
df.shape
# Out:
# (149, 6)

# %%
sns.boxplot(x='SepalWidthCm', data=df)
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
Q1=nm.percentile(df['SepalLengthCm'],25,interpolation='midpoint')

# %%
Q3=nm.percentile(df['sepal.length'],75,interpolation='midpoint')
